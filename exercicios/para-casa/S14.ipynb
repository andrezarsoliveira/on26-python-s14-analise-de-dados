# %%
#importando bibliotecas
import pandas as pd

# %% [markdown]
# Coleta de base de dados
# A base de dados tem 3 tabelas diferentes:
#
# (olist_customers_dataset)
# detalhes de pagamento dos pedidos (olist_products_dataset)
# detalhes do consumidor que fez os pedidos (olist_sellers_dataset)

# %%
df_customer = pd.read_csv('/content/olist_customers_dataset.csv')
df_customer
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_product = pd.read_csv('/content/olist_products_dataset.csv')
df_product
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_seller = pd.read_csv('/content/olist_sellers_dataset.csv')
df_seller
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
#Quais dados temos na tabela cliente:
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#Quais dados temos na tabela produtos:
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
#Quais dados temos na tabela vendedor:
df_seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# #Limpeza dos dados
#
# * Remoção de colunas que não serão utilizadas

# %%
#Excluindo as colunas de id único do cliente e código postal que não será utilizada:
columns_drop_customer = ['customer_id','customer_zip_code_prefix']

df_customer = df_customer.drop(columns_drop_customer, axis=1)
df_customer
# Out:
#                      customer_unique_id          customer_city customer_state
# 0      861eff4711a542e4b93843c6dd7febb0                 franca             SP
# 1      290c77bc529b7ac935b93aa66c333dc3  sao bernardo do campo             SP
# 2      060e732b5b29e8181a18229c7b0b2b5e              sao paulo             SP
# 3      259dac757896d24d7702b9acbbff3f3c        mogi das cruzes             SP
# 4      345ecd01c38d18a9036ed96c73b8d066               campinas             SP
# ...                                 ...                    ...            ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8              sao paulo             SP
# 99437  d52a67c98be1cf6a5c84435bd38d095d        taboao da serra             SP
# 99438  e9f50caf99f032f0bf3c55141f019d99              fortaleza             CE
# 99439  73c2643a0a458b49f58cea58833b192e                 canoas             RS
# 99440  84732c5050c01db9b23e19ba39899398                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
#Excluindo as colunas de prefixo de CEP
columns_drop_sellers = ['seller_zip_code_prefix']
df_seller = df_seller.drop(columns_drop_sellers, axis=1)
df_seller
# Out:
#                              seller_id        seller_city seller_state
# 0     3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1     d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2     ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4     51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
# ...                                ...                ...          ...
# 3090  98dddbc4601dd4443ca174359b237166            sarandi           PR
# 3091  f8201cab383e484733266d1906e2fdfa            palhoca           SC
# 3092  74871d19219c7d518d0090283e03c137          sao paulo           SP
# 3093  e603cf3fec55f8697c9059638d6c8eb5            pelotas           RS
# 3094  9e25199f6ef7e7c347120ff175652c3b            taubate           SP
#
# [3095 rows x 3 columns]

# %%
#Excluindo as colunas de produtos que não serão utilizadas
columns_drop_products = ['product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm']

df_product = df_product.drop(columns=columns_drop_products, axis=1)
df_product
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght
# 0                     40.0
# ...

# %% [markdown]
# #Insights

# %%
df_customer_city = df_customer['customer_city'].value_counts()
df_customer_city.head(5)
# Out:
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
# Name: customer_city, dtype: int64

# %%
df_customer_state = df_customer ['customer_state'].value_counts()
df_customer_state.head(5)
# Out:
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# Name: customer_state, dtype: int64

# %%
df_product_category = df_product['product_category_name'].value_counts()
df_product_top5 = df_product_category.head(5)
df_product_category
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %% [markdown]
# * Qual a cidade de origem dos clientes? Em primeiro lugar São Paulo, seguido do Rio de Janeiro e por fim Belo Horizonte.
# * Qual o estado dos clientes? Em primeiro lugar São Paulo, seguido do Rio de Janeiro e por fim Minas Gerais.
# * Quais são os produtos mais vendidos? As 5 categorias de produtos mais vendidos são: Cama, mesa e banho; Esporte e lazer; Movéis e decoração; Beleza e Saúde; Utilidades domésticas
# * Quais são os protudos menos vendidos? As 5 categorias de produtos menos vendidos são: Vestuário infanto-juvenil; Casa e conforto; Pc gamer; Seguros e serviços; CDS e DVDS musicais.
# * Quantos clientes foram registrados em SP nessa base de dados? Foram registrados 41746 clientes.

# %% [markdown]
# #Gráficos a partir das bases de dados utilizadas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(x=df_product_top5.index, y=df_product_top5.values, hue=df_product_top5.index, dodge=True)
plt.title('Comparação de Tipos de Categoria de Produtos')
plt.xlabel('Categoria')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.show()

# %%
top_10_state = df_customer_state.nlargest(10)

top_10_state.plot(kind="bar", edgecolor='black')

plt.xlabel("Estado")
plt.ylabel("Quantidade")
plt.title("Top 10 estados com mais clientes")

plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Gráfico de Comparação entre os top 5 estados com mais clientes')
plt.show()

# %%
#Trabalho realizado em conjunto com Marianna Carvalho
